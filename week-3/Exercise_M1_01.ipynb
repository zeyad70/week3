# %%
import pandas as pd
import sys
sys.executable
# Out:
# 'c:\\Users\\hp\\Desktop\\bootcamp\\week-3\\.venv\\Scripts\\python.exe'

# %%
# !{sys.executable} -m pip install matplotlib seaborn
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\desktop\bootcamp\week-3\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Installing collected packages: contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 matplotlib-3.10.8 seaborn-0.13.2
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Exercise M1.01

# %%
df = pd.read_csv("./datasets/penguins_classification.csv")
df.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie

# %%
features = ["culmen_length_mm", "culmen_depth_mm"]
target = "species"
features, target
# Out:
# (['culmen_length_mm', 'culmen_depth_mm'], 'species')

# %%
numerical_features = df.select_dtypes(include="number").columns
categorical_features = df.select_dtypes(include="object").columns


len(numerical_features), len(categorical_features)
# Out:
# (2, 1)

# %%
df.rename(columns={
    "Culmen Length (mm)": "culmen_length_mm",
    "Culmen Depth (mm)": "culmen_depth_mm",
    "Species": "species"
}, inplace=True)


df.columns
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'species'], dtype='object')

# %%
df["species"].value_counts()
# Out:
# species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %%
numerical_features = ["culmen_length_mm", "culmen_depth_mm"]

# %%
import matplotlib.pyplot as plt

df[numerical_features].hist(figsize=(10,5))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

sns.pairplot(df, vars=numerical_features, hue="species")
plt.show()
